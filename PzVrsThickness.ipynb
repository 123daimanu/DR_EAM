# %%
import numpy as num
import pylab as lab
# %matplotlib inline

# %%
#E=0
thick=[2,4,6,8,10,12]
pz=[-1.35983e-32,6.62278e-32,-1.31455e-30,-3.7626e-31,-2.68343e-30,9.59815e-31]
pz=num.array(pz)
thick=2*num.array(thick)

# %%
lab.plot(thick,abs(pz),"o")
lab.show()

# %%
#E=1e-6
thick=[2,4,6,8,10,12]
pz=[4.0434e-33,-5.83319e-32,-3.70383e-31,-5.1228e-31,1.34188e-30,-1.57038e-30]
pz=num.array(pz)
thick=2*num.array(thick)
lab.plot(thick,abs(pz),"o")
lab.show()

# %%
#E=1e-4
thick=[2,4,6,8,10,12]
pz=[2.30203e-33,-2.14715e-31,1.06987e-30, 2.16374e-30,9.06961e-30,7.24588e-30]
pz=num.array(pz)
thick=2*num.array(thick)
lab.plot(thick,abs(pz),"o")
lab.show()

# %%
#E=1e-2
thick=[2,4,6,8,10,12]
pz=[2.30203e-33,-2.14715e-31,1.06987e-30, 2.16374e-30,9.06961e-30,7.24588e-30]
pz=num.array(pz)
thick=2*num.array(thick)
lab.plot(thick,abs(pz),"o")
lab.show()

# %%
#thick=14 efiled=xe-2 pz=xe-27
e=[2e8,3e8,4e8,5e8]
p=[2.73e-27,4.09e-27,5.47e-27,6.83e-27]
lab.plot(e,p,"o-")
lab.xlabel("E ($V\; m^{-1})$")
lab.ylabel("pz ($C\; m$)")
lab.title("Dipole moment Vs Electric Field")
lab.savefig("linear_EvrsP.eps")

# %%
al=(p[0]-p[1])*1e-27/((e[0]-e[1])*1e-2)
al=al/1.1126e-30/2800
al
# Out:
# 43.65578695975963

# %%
#thick=15 efiled=xe-2 pz=xe-27
e=[2,3,4,5]#,4,5]
p=[3.36,5.044, 6.72663,8.408]#,5.47,6.83]
lab.plot(e,p,"*-")
lab.xlabel("E(_e-2)V/A")
lab.ylabel("pz(_e-27)c/m")
lab.savefig("linear_EvrsP.eps")

# %%
al=(p[2]-p[1])*1e-27/((e[2]-e[1])*1e-2)
al=al/1.1126e-30/3000
al
# Out:
# 50.41134879261791

# %%
#thick=15 efiled=xe-2 pz=xe-27
e=[2,3,4,5]#,4,5]
p=[3.36,5.044, 6.72663,8.408]#,5.47,6.83]
lab.plot(e,p,"*-")
lab.xlabel("E(_e-2)V/A")
lab.ylabel("pz(_e-27)c/m")
lab.savefig("linear_EvrsP.eps")

# %%
x=num.linspace(0,8,100)
m=num.tanh(x/2)
lab.plot(x,m)
lab.xlabel("B")
lab.ylabel("M")
lab.savefig("jzero.png")
lab.show()

# %%
x=num.linspace(0.01,2.269,1000)
xin=1/x
m=(1-num.sinh(2*xin)**-.25)**(1/8.)
lab.plot(x,m)
lab.xlabel("T")
lab.ylabel("M")
lab.savefig("onszar.png")
lab.show()

# %%
#for pt111 E=10-2v/A


6.22456e-28/12
# Out:
# 5.187133333333333e-29

# %%
8.0787e-28/13
# Out:
# 6.214384615384616e-29

# %%
1.01564e-27/14
# Out:
# 7.25457142857143e-29

# %%
1.27515e-27/15
# Out:
# 8.501e-29

# %%
#pt 100 E=10-2v/A

2.87343e-30/2
# Out:
# 1.436715e-30

# %%
2.73243e-29/4
# Out:
# 6.831075e-30

# %%
9.71628e-29/6
# Out:
# 1.61938e-29

# %%
2.40882e-28/8
# Out:
# 3.011025e-29

# %%
4.83738e-28/10
# Out:
# 4.83738e-29

# %%
8.49858e-28/12
# Out:
# 7.082150000000001e-29

# %%
t=[2,4,6,8,10,12]
p1=num.array([2.87343e-30,2.73243e-29,9.71628e-29,2.40882e-28,4.83738e-28,8.49858e-28])
p2=num.array([6.22456e-28,8.0787e-28,1.01564e-27,1.27515e-27])
lab.plot(t,p,'*-')
lab.xlabel("thickness")
lab.ylabel("dipole/thickness")
lab.savefig("e-2100.eps")

# %%
area=48.0099*27.718586
thick=num.array([11.316,24.895,38.474,52.053,65.633,79.212])
thick1=num.array([79.212,86.0021,92.7918,99.5814])
v1=area*thick
v2=area*thick1
con=1/3.33564e-30
p1D=con*p1
p2D=con*p2
P1D=p1D/v1
P2D=p2D/v2

# %%
lab.plot(thick,P1D,"*-",thick1,P2D,'-o')
lab.xlabel("thickness ang")
lab.ylabel("Pz D/ang^3")

# %%
thick
# Out:
# array([ 11.316,  24.895,  38.474,  52.053,  65.633,  79.212])
