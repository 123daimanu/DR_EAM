# %%
# extract information from dump file.
import numpy as num
import matplotlib.pyplot as plt
from matplotlib import use
import pylab as lab
from scipy import constants
from matplotlib import rcParams
import pandas as pan
import os

from scipy.optimize import curve_fit

os.chdir("/home/hbhattar/afs/Hemanta/metals/pythonScripts/function")

import FDEAM as feam

os.chdir("/home/hbhattar/afs/Hemanta/metals/pythonScripts/")



#setting different parameteres
params = {
    'font.family':'serif',
   'axes.labelsize': 12,
   'font.size': 12,
   'legend.fontsize': 12,
   'xtick.labelsize': 12,
   'ytick.labelsize': 12,
    'axes.labelpad' : 0,
   'text.usetex': False,
   'figure.figsize': [4,4],
    'figure.max_open_warning': 0
   }
rcParams.update(params)
# %matplotlib inline

# %% [markdown]
# ## No of layers =18, small cut off 8 and without Sufrace term

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z18WithoutSO_6K_9E_0.02.dump",100,nMol['18'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['18'])
begin=75

eavz18=[]
eavx18=[]
eavy18=[]
chav18=[]
zav18=[]
for counter in range(len(ass)):
    eavz18.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav18.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx18.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy18.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav18.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav18)
lab.xlim([-1,19])
lab.show()

# %% [markdown]
# ## No of layers =18, small cut off 8 and with Sufrace term

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z18WithSO_6K_9E_0.02.dump",100,nMol['18'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['18'])
begin=75

eavz18s=[]
eavx18s=[]
eavy18s=[]
chav18s=[]
zav18s=[]
for counter in range(len(ass)):
    eavz18s.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav18s.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx18s.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy18s.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav18s.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav18s)
lab.xlim([-1,19])
lab.show()

# %%
lab.plot(chav18s,label="S")
lab.plot(chav18,'-r',label="NS")
lab.xlim([-1,19])
lab.xlabel("Layers")
lab.legend(loc="lower right")
lab.ylabel("<q>")
lab.show()

# %% [markdown]
# ## No of layers = 21, small cut off 8 and without Sufrace term

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z21WithoutSO_6K_9E_0.02.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
begin=75

eavz21=[]
eavx21=[]
eavy21=[]
chav21=[]
zav21=[]
for counter in range(len(ass)):
    eavz21.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %% [markdown]
# ## No of layers = 21, small cut off 8 and with Sufrace term

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z21WithSO_6K_9E_0.02.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
begin=75

eavz21s=[]
eavx21s=[]
eavy21s=[]
chav21s=[]
zav21s=[]
for counter in range(len(ass)):
    eavz21s.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21s.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21s.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21s.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21s.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav21s,label='S')
lab.plot(chav21,'-r',label = 'NS')
lab.xlabel("Layers")
lab.ylabel("<q>")
lab.legend()
lab.show()

# %%
lab.plot(chav21,'r')
lab.plot(chav18)
lab.xlabel("Layers")
lab.ylabel("<q>")
lab.show()

# %%
lab.plot(chav21s,'ro')
lab.plot(chav18s,'bo')
lab.xlabel("Layers")
lab.ylabel("<q>")
lab.show()

# %%
lab.plot(chav21s[::-1],'ro')
lab.plot(chav18s[::-1],'bo')
lab.xlabel("Layers")
lab.ylabel("<q>")

# %%
lab.plot(chav21s,'ro')
lab.plot(chav18s,'bo')
lab.xlabel("Layers")
lab.ylabel("<q>")

# %%
lab.plot(chav21[::-1],'or')
lab.plot(chav18[::-1],'go')
lab.xlabel("Layers")
lab.ylabel("<q>")

# %%
lab.plot(chav21,'or')
lab.plot(chav18,'go')
lab.xlabel("Layers")
lab.ylabel("<q>")

# %% [markdown]
# # Comparison for different K diffferent E, with surface term

# %% [markdown]
# ## With different E

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z21WithSO_6K_9E_0.04.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
begin=75

eavz21sde = []
eavx21sde = []
eavy21sde = []
chav21sde = []
zav21sde = []
for counter in range(len(ass)):
    eavz21sde.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21sde.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21sde.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21sde.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21sde.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav21s)
lab.plot(chav21sde,'r')
lab.xlabel("Layers")
lab.ylabel("<q>")

# %%
lab.plot(eavz21s,'--o')
lab.plot(eavz21sde,'ro')
lab.xlabel("Layers")
lab.ylabel("<E>")

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z18WithSO_6K_9E_0.04.dump",100,nMol['18'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['18'])
begin=75

eavz18sde = []
eavx18sde = []
eavy18sde = []
chav18sde = []
zav18sde = []
for counter in range(len(ass)):
    eavz18sde.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav18sde.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx18sde.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy18sde.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav18sde.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav18s)
lab.plot(chav18sde,'r')
lab.xlabel("Layers")
lab.ylabel("<q>")

# %%
lab.plot(eavz18s,'-o')
lab.plot(eavz18sde,'-or')
lab.xlabel("Layers")
lab.ylabel("<E>")

# %% [markdown]
# ## With Different K

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z21WithSO_6K_5.5E_0.02.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
begin=75

eavz21sdk = []
eavx21sdk = []
eavy21sdk = []
chav21sdk = []
zav21sdk = []
for counter in range(len(ass)):
    eavz21sdk.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21sdk.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21sdk.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21sdk.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21sdk.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav21s)
lab.plot(chav21sdk,'r')

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z18WithSO_6K_5.5E_0.02.dump",100,nMol['18'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['18'])
begin=75

eavz18sdk = []
eavx18sdk = []
eavy18sdk = []
chav18sdk = []
zav18sdk = []
for counter in range(len(ass)):
    eavz18sdk.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav18sdk.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx18sdk.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy18sdk.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav18sdk.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(chav18s[:],'o-')
lab.plot(chav18sdk[:],'ro-')

# %%
lab.plot(chav18s[:5],'o-')
lab.plot(chav18sdk[:5],'ro-')

# %%
lab.plot(chav18s[4:-4],'o')
lab.plot(chav18sdk[4:-4],'ro')

# %%
lab.plot(eavz21s,'o-')
lab.axhline(y=0,color='red',linestyle='--')
lab.show()

# %%
dev=num.array(chav18s)-num.array(chav18sdk)

# %%
lab.plot(dev,'-o')
lab.axhline(y=0,color='red',linestyle='--')
lab.show()

# %%
eavz21s
# Out:
# [0.014603865000450498,
#  -0.00025462005980999105,
#  0.0001931308353586468,
#  0.00085815844483110178,
#  0.00067490568070606286,
#  0.00066869871180415524,
#  0.00073805530663687132,
#  0.00067229492672060101,
#  0.00056726887980232052,
#  0.00066232468449747329,
#  0.00075673848702245401,
#  0.00066338087380727652,
#  0.0006083469040171894,
#  0.00070157448199959405,
#  0.00073432434822265314,
#  0.00066070554113962024,
#  0.00069931002837800012,
#  0.0008949255770734592,
#  0.00020461167150674972,
#  -9.679888758364931e-05,
#  0.014656799353981079]

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':4032,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/21LCO_6K_10E_0.02.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
begin=75

eavz21LCs=[]
eavx21LCs=[]
eavy21LCs=[]
chav21LCs=[]
zav21LCs=[]
for counter in range(len(ass)):
    eavz21LCs.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21LCs.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21LCs.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21LCs.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21LCs.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(eavz21LCs[4:-4],'-o')
lab.plot(eavz21s[4:-4],'--or')
lab.axhline(y=0,color='red',linestyle='--')
lab.show()

# %%
lab.plot(chav21LCs,'-o')
lab.plot(chav21s,'--or')
lab.axhline(y=0,color='green',linestyle='--')

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':4032,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/21LCWithoutSO_6K_10E_0.02.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
begin=75

eavz21LC=[]
eavx21LC=[]
eavy21LC=[]
chav21LC=[]
zav21LC=[]
for counter in range(len(ass)):
    eavz21LC.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21LC.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21LC.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21LC.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21LC.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(eavz21LCs,'-o')
lab.axhline(y=0,color='red',linestyle='--')
lab.plot(eavz21s,'-go')

# %%
lab.plot(ezs)
lab.show()

# %%
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':10080,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractorIncomplete("../KTuningPolynomialSelf/Simulation/21VLCSO_6K_10E_0.02.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
frames=rawData["CFrame"]
print(frames)
begin=75

eavz21VLC=[]
eavx21VLC=[]
eavy21VLC=[]
chav21VLC=[]
zav21VLC=[]
for counter in range(len(ass)):
    eavz21VLC.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21VLC.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21VLC.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21VLC.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21VLC.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
# Out:
# 100

# %%
lab.plot(eavz21VLC,'m')
lab.plot(eavz21LCs)
lab.xlabel("Layers")
lab.ylabel("<E>")
lab.axhline(y=0,color='red',linestyle='--')

# %%
lab.plot(chav21VLC,'--g')
lab.plot(chav21LCs)
lab.xlabel("Layers")
lab.ylabel("<q>")
lab.show()

# %%
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':3240,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractorIncomplete("../KTuningPolynomialSelf/Simulation/PtEwald.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
frames=rawData["CFrame"]
print(frames)
begin=0

eavz21EVLC=[]
eavx21EVLC=[]
eavy21EVLC=[]
chav21EVLC=[]
zav21EVLC=[]

for counter in range(len(ass)):
    eavz21EVLC.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21EVLC.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21EVLC.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21EVLC.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21EVLC.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
# Out:
# 100

# %%
lab.plot(eavz21EVLC[:],'o')
lab.axhline(y=0,color='red',linestyle='--')
lab.xlabel("Layers")
lab.ylabel("<E>")
lab.ylim([-.005,0.021])
# Out:
# (-0.005, 0.021)

# %%
eavz21EVLC[0]-0.02
# Out:
# -0.001681751687681074

# %%
#lab.plot(chav21EVLC[:],'o-')
lab.plot(chav21VLC[:],'*-g')
lab.axhline(y=0,color='red',linestyle='--')

# %%
lab.plot(chav21VLC[10-2:10+3],'o')

# %%
frames=100
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':1512,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractor("../KTuningPolynomialSelf/Simulation/PtSlab111Z18WithSO_6K_10E_0.dump",100,nMol['18'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['18'])
begin=0

eavz18E0s=[]
eavx18E0s=[]
eavy18E0s=[]
chav18E0s=[]
zav18E0s=[]
for counter in range(len(ass)):
    eavz18E0s.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav18E0s.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx18E0s.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy18E0s.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav18E0s.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))

# %%
lab.plot(num.array(chav18E0s)-num.array(chav18s))

# %%
lab.plot(eavz18E0s)
lab.show()

# %%
lab.plot(chav18E0s)
lab.show()

# %%
nMol={'9':648,'12':864,'15':1080,'18':1296,'21':3240,'24':1728,'27':1944,'30':2160,'33':2376,'36':2592,'39':2808}
rawData=feam.DumpExtractorIncomplete("../KTuningPolynomialSelf/Simulation/PtEwaldE0.dump",100,nMol['21'],0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol['21'])
frames=rawData["CFrame"]
print(frames)
begin=0

eavz21EVLCE0=[]
eavx21EVLCE0=[]
eavy21EVLCE0=[]
chav21EVLCE0=[]
zav21EVLCE0=[]

for counter in range(len(ass)):
    eavz21EVLCE0.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21EVLCE0.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21EVLCE0.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21EVLCE0.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21EVLCE0.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
# Out:
# 100

# %%
lab.plot(eavz21EVLCE0,'o-')

# %%
a="ram"

# %%
a[:-1]
# Out:
# 'ra'

# %%
k=[1,
  2,
  3]

# %%
k
# Out:
# [1, 2, 3]

# %%
eAffinityIoni = {
        "Cu_FQ":[-119.235,0,745.48,1957.92,3555,5536],
        "Ag_FQ":[-125.6,0,731.00,2072.93,3358,4728],
        "Au_FQ":[-222.747,0,890.13,1949.3,2890],
        "Ni_FQ":[-111.65,0,737.14,1753.03,3395.0,5299],
        "Pd_FQ":[-54.067,0,804.38,1875,3177,4438],
        "Pt_FQ":[-205.041,0,864.40,1791,2800,4150],
        "Al_FQ":[-41.762,0,577.54,1816.68,2744.78],
        "Pb_FQ":[-34.4204,0,715.60,1450.42,3081.17,4084.47],
        "Fe_FQ":[-14.785,0,762.47,1562.98,2957.4,5298],
        "Mo_FQ":[-72.10,0,684.32,1559,2618,3891],
        "Ta_FQ":[-31.00,0,728.42,1560,2230,3380],
        "W_FQ":[-78.76,0,758.76,1580,2510,3690],
        "Mg_FQ":[40,0,737.75,1450.68,7732.68,10542.51],
        "Co_FQ":[-63.898,0,760.40,1648.39,3232.3,4947,7671],
        "Ti_FQ":[-8,0,658.81,1309.84,2652.55],
        "Zr_FQ":[-41.1,0,640.10,1267,2236,3320.87]}

# %%
e={}
for var in eAffinityIoni:
    l=[]
    lis=var
    l.append(eAffinityIoni[var][0])
    l.append(eAffinityIoni[var][1])
    temp=0
    for data in eAffinityIoni[var][2:]:
        temp+=data
        l.append(temp)
        
    e[var]=l

# %%
e
# Out:
# {'Ag_FQ': [-125.6, 0, 731.0, 2803.93, 6161.93, 10889.93],
#  'Al_FQ': [-41.762, 0, 577.54, 2394.2200000000003, 5139.0],
#  'Au_FQ': [-222.747, 0, 890.13, 2839.43, 5729.43],
#  'Co_FQ': [-63.898, 0, 760.4, 2408.79, 5641.09, 10588.09, 18259.09],
#  'Cu_FQ': [-119.235, 0, 745.48, 2703.4, 6258.4, 11794.4],
#  'Fe_FQ': [-14.785, 0, 762.47, 2325.45, 5282.85, 10580.85],
#  'Mg_FQ': [40, 0, 737.75, 2188.4300000000003, 9921.11, 20463.620000000003],
#  'Mo_FQ': [-72.1, 0, 684.32, 2243.32, 4861.32, 8752.32],
#  'Ni_FQ': [-111.65, 0, 737.14, 2490.17, 5885.17, 11184.17],
#  'Pb_FQ': [-34.4204, 0, 715.6, 2166.02, 5247.1900000000005, 9331.66],
#  'Pd_FQ': [-54.067, 0, 804.38, 2679.38, 5856.38, 10294.380000000001],
#  'Pt_FQ': [-205.041, 0, 864.4, 2655.4, 5455.4, 9605.4],
#  'Ta_FQ': [-31.0, 0, 728.42, 2288.42, 4518.42, 7898.42],
#  'Ti_FQ': [-8, 0, 658.81, 1968.6499999999999, 4621.2],
#  'W_FQ': [-78.76, 0, 758.76, 2338.76, 4848.76, 8538.76],
#  'Zr_FQ': [-41.1, 0, 640.1, 1907.1, 4143.1, 7463.97]}

# %%
nMol=1536
rawData=feam.DumpExtractorIncomplete("../FDEAMCrystalCalculations/Ag.dump",100,nMol,0)
[vxs,vys,vzs]=rawData["velocity"]
[xs,ys,zs]=rawData["position"]
[cs,ws]=rawData["chargeQV"]
[exs,eys,ezs]=rawData["electricField"]
[layerss,ass]=feam.Layers(zs,nMol)
frames=rawData["CFrame"]
print(frames)
begin=0

eavz21EVLCE0=[]
eavx21EVLCE0=[]
eavy21EVLCE0=[]
chav21EVLCE0=[]
zav21EVLCE0=[]

for counter in range(len(ass)):
    eavz21EVLCE0.append(num.sum(num.sum(ezs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    chav21EVLCE0.append(num.sum(num.sum(cs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavx21EVLCE0.append(num.sum(num.sum(exs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    eavy21EVLCE0.append(num.sum(num.sum(eys[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
    zav21EVLCE0.append(num.sum(num.sum(zs[begin:,layerss[counter][0]],axis=1)/len(layerss[counter][0]))/(frames-begin))
# Out:
# Error: Incomplete file
# 100

# %%
#lab.plot(cs)
lab.plot(cs[begin:,layerss[-1][0]])

lab.show()

# %%
lab.plot(chav21EVLCE0)

# %%
1.5e5*(10**(-22/5))/((11/6)**(6/5)*(11/5))
# Out:
# 1.311531894666025

# %%
10**(2/5)
# Out:
# 2.51188643150958

# %%
40,0, 737.75, 1450.68, 9183.36, 19725.870000000003
