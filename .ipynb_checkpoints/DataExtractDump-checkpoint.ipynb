# %% [markdown]
# Program that extracts the information about the position and velocity of atoms in each sites along with charge and charge velocity at those sites in each frames.
#
#
# path="" refers to the path of the dump file from which data is to be extracted
#
# frames=------ number of frames during openmd execution
#
# atomNumber=----------- total number of atomic sites during program execution

# %%
# extract information from dump file.
import numpy as num
import matplotlib.pyplot as plt
import pylab as lab
from scipy import constants
# %matplotlib inline

#==================================================================================================================
path="/home/hbhattar/afs/Hemanta/metals/KDetermine/pt111_highfield/E7/Pt_test_K2000_E10.dump";                  #the path of the file
frames=100;              #total frames in dump file
atomNumber=972;         #total atoms in lattice


#====================================================================================================================


fileDump=open(path)  #dump file for info extraction
linesDump=fileDump.readlines()

processP="Wait"
processC="Wait"


#information storage matrix 
#posiiton and velocity storage
x=num.zeros((frames,atomNumber))
y=num.zeros((frames,atomNumber))
z=num.zeros((frames,atomNumber))
vx=num.zeros((frames,atomNumber))
vy=num.zeros((frames,atomNumber))
vz=num.zeros((frames,atomNumber))


#charge and velocity storage matrix
c=num.zeros((frames,atomNumber))
cv=num.zeros((frames,atomNumber))
e=num.zeros((frames,atomNumber))
#frame count initilization
fCount=0
index=0  #index for the atoms
for line in linesDump:
    linesSplit=str.split(line)
    length=len(linesSplit)
    
    if(length!=0 and linesSplit[0]=="<StuntDoubles>" and processP=="Wait"):
        processP="Start"
        continue;
        
    elif(length!=0 and linesSplit[0]=="</StuntDoubles>" and processP=="Start"):
        processP="Wait"
        index=0
        continue;
        
    elif(length!=0 and linesSplit[0]=="<SiteData>" and processC=="Wait"):
        processC="Start"
        continue;
        
    elif(length!=0 and linesSplit[0]=="</SiteData>" and processC=="Start"):
        fCount=fCount+1
        index=0;
        processC="Wait"
        continue;
   
    elif(fCount>=frames):
        break;
        
    else:
        processP=processP;
        processC=processC;
        
        
    if (processP=="Start"):
        x[fCount][index]=float(linesSplit[2])
        y[fCount][index]=float(linesSplit[3])
        z[fCount][index]=float(linesSplit[4])
        vx[fCount][index]=float(linesSplit[5])
        vy[fCount][index]=float(linesSplit[6])
        vz[fCount][index]=float(linesSplit[7])
        index=index+1
        
    if(processC=="Start"):
        c[fCount][index]=float(linesSplit[3])
        cv[fCount][index]=float(linesSplit[4])
        e[fCount][index]=float(linesSplit[7])
        index=index+1

# %%
plt.plot(e[99,:],label="y")
#plt.plot(x[:,972],label="x")
#plt.plot(vz[:,972],label="z")
#plt.legend(loc=2)
#plt.plot(z[:,972])
#plt.xlim([0,100])
#plt.ylim([-.00010,0.00010])
plt.show()

# %%
e
# Out:
# array([[ 0.230609,  0.230609,  0.230609, ...,  0.230609,  0.230609,
#          0.230609],
#        [ 0.230609,  0.230609,  0.230609, ...,  0.230609,  0.230609,
#          0.230609],
#        [ 0.230609,  0.230609,  0.230609, ...,  0.230609,  0.230609,
#          0.230609],
#        ...,
#        [ 0.230609,  0.230609,  0.230609, ...,  0.230609,  0.230609,
#          0.230609],
#        [ 0.230609,  0.230609,  0.230609, ...,  0.230609,  0.230609,
#          0.230609],
#        [ 0.230609,  0.230609,  0.230609, ...,  0.230609,  0.230609,
#          0.230609]])

# %%
plt.plot(y[0,:],range(atomNumber),'o')
plt.show()

# %%
frame=99
# 111 14layers
#pos=[-46,-44,-41,-39,-37,-35,-32,-30,-28,-26,-23,-19,-16,-14,-12,-10,-7,-5,-3,-1,1,3,5,7,10,12,14,16,19,23,26,28,30,32,35,37,39,41,44,46,10000]
#111 15 layers
pos=[-49,-47,-45,-43,-40,-38,-36,-33,-31,-29,-27,-24,-22,-20,-18,-15,-13,-11,-9,-6,-4,-2,0,2,4,6,9,11,13,15,18,20,22,24,27,29,31,33,36,38,40,43,45,47,49,10000]

#111 12 layers
#pos=[-39,-37,-35,-32,-30,-28,-26,-23,-22,-19,-16,-14,-12,-10,-7,-5,-3,-1,1,3,5,7,10,12,14,16,19,22,23,25,28,30,32,35,37,39,100000]
charge_layer=[]
low=-1000000

for var in pos:
    up=var
    zpos=num.logical_and(z[frame,:]<var,z[frame,:]>low)
    numAtoms=sum(zpos)
    charge_layer.append(num.sum(c[frame,:][zpos])/float(numAtoms))
    low=var
# Out:
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:16: RuntimeWarning: invalid value encountered in double_scalars

# %%
charge_layer
# Out:
# [-0.079197583099999996,
#  -0.077703365450000006,
#  -0.073318286499999996,
#  -0.069804538199999988,
#  -0.065993327349999992,
#  -0.0624368696,
#  -0.058754735849999996,
#  -0.054957351500000001,
#  -0.051295550650000001,
#  -0.047808949849999997,
#  -0.043949306699999996,
#  -0.040271210699999997,
#  -0.036726762749999996,
#  -0.033010065299999995,
#  -0.029226564850000001,
#  -0.025604875099999997,
#  -0.022045027450000001,
#  -0.018321628850000004,
#  -0.014854807249999999,
#  -0.010990773895000002,
#  -0.0074930341800000001,
#  -0.0036959577075000006,
#  nan,
#  -6.9599981744999988e-05,
#  0.0036993843000000005,
#  0.0072880511999999995,
#  0.01091874254,
#  0.0144902763,
#  0.018276871849999998,
#  0.021978769100000004,
#  0.025598042850000002,
#  0.029347560999999994,
#  0.032896279050000005,
#  0.036610988149999996,
#  0.040389084950000001,
#  0.044034415700000003,
#  0.047495830150000008,
#  0.051250729599999996,
#  0.054924444700000005,
#  0.058559253499999998,
#  0.062346302950000008,
#  0.066041540849999997,
#  0.069793756850000013,
#  0.073420376900000001,
#  0.076117413250000002,
#  0.082052057600000006]

# %%
plt.plot((num.array((charge_layer))),'o')
plt.grid()
#plt.savefig("15E0_111.eps")

# %%
lab.plot(num.sort(c[99]))

# %%
lab.plot(num.sum(c,1))

# %%
num.sum(c[99,:])
# Out:
# 1.118951499977372e-06

# %%
200*15*3
# Out:
# 9000

# %%
num.sum(c)
# Out:
# 0.0002118630068730365
