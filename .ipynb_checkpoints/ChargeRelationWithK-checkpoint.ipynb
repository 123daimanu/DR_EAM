# %%
import numpy as num
import scipy as sci
import pandas as pan
import pylab as lab
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pan.read_csv('/home/hbhattar/PERSONAL/SimulationTest/PtOxides/PtO/PtOPolyFitK/charge.dat',sep=" ",\
                  names=["KPt","KO","qO","index","zero","cwed","c","w","ex","ey","ez","d"])

# %%
data.head()
# Out:
#    KPt  KO   qO  index  zero  cwed         c    w        ex        ey  \
# 0    5   5  400    508     0  cwed -41.42385  0.0 -0.137307 -0.137307
# 1    5   6  400    508     0  cwed -45.75315  0.0 -0.151226 -0.151226
# 2    5   7  400    508     0  cwed -50.00090  0.0 -0.164883 -0.164883
# 3    5   8  400    508     0  cwed -54.13804  0.0 -0.178184 -0.178184
# 4    5   9  400    508     0  cwed -58.12296  0.0 -0.190996 -0.190996
#
#          ez         d
# 0  0.176970  5.819479
# 1  0.195139  3.404706
# 2  0.212965  1.035424
# 3  0.230328 -1.272166
# 4  0.247052 -3.494849

# %%
redData=data[["KPt","KO","qO","c","d"]]
redData.head()
# Out:
#    KPt  KO   qO         c         d
# 0    5   5  400 -41.42385  5.819479
# 1    5   6  400 -45.75315  3.404706
# 2    5   7  400 -50.00090  1.035424
# 3    5   8  400 -54.13804 -1.272166
# 4    5   9  400 -58.12296 -3.494849

# %%
d=redData
d.head()
# Out:
#    KPt  KO   qO         c         d
# 0    5   5  400 -41.42385  5.819479
# 1    5   6  400 -45.75315  3.404706
# 2    5   7  400 -50.00090  1.035424
# 3    5   8  400 -54.13804 -1.272166
# 4    5   9  400 -58.12296 -3.494849

# %%
KQ=[[x,y] for x in range(5,31) for y in range(400,401)]
KK=[[x,y] for x in range(5,31) for y in range(5,31)]

# %%
for var in KQ:
    d=redData[num.logical_and(redData["KPt"]==var[0],redData["qO"]==var[1])]
    lab.title("%d||%.2f"%(var[0],var[1]))
    lab.ylim([0,1])
    lab.plot(d["KO"],abs(d["c"]),'ro')
    #lab.fill_between(d["KO"],65,75,facecolor='green',alpha=0.2)
    #lab.vlines(d["KO"],50,80,'b',alpha=.2,linestyle='dashed')
    #lab.xticks(d["KO"])
    #lab.fill_between(abs())
    lab.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/cbook.py in iterable(obj)
#     689     try:
# --> 690         iter(obj)
#     691     except TypeError:
#
# TypeError: 'NoneType' object is not iterable
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-297-572458255d32> in <module>()
#       1 for var in KQ:
#       2     d=redData[num.logical_and(redData["KPt"]==var[0],redData["qO"]==var[1])]
# ----> 3     lab.title("%d||%.2f"%(var[0],var[1]))
#       4     lab.ylim([0,1])
#       5     lab.plot(d["KO"],abs(d["c"]),'ro')
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in title(s, *args, **kwargs)
#    1444
#    1445     """
# -> 1446     return gca().set_title(s, *args, **kwargs)
#    1447
#    1448 ## Axis ##
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/pyplot.py in gca(**kwargs)
#     934     matplotlib.figure.Figure.gca : The figure's gca method.
#     935     """
# --> 936     return gcf().gca(**kwargs)
#     937
#     938 # More ways of creating axes:
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py in gca(self, **kwargs)
#    1357
#    1358         # no axes found, so create one which spans the figure
# -> 1359         return self.add_subplot(1, 1, 1, **kwargs)
#    1360
#    1361     def sca(self, a):
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1003                     self._axstack.remove(ax)
#    1004
# -> 1005             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1006
#    1007         self._axstack.add(key, a)
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      71
#      72         # _axes_class is set in the subplot_class_factory
# ---> 73         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      74
#      75     def __reduce__(self):
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, axisbg, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     513         self._hold = rcParams['axes.hold']
#     514         self._connected = {}  # a dict from events to (id, func)
# --> 515         self.cla()
#     516         # funcs used to format x and y - fall back on major formatters
#     517         self.fmt_xdata = None
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in cla(self)
#     914         self.yaxis.cla()
#     915         for name, spine in six.iteritems(self.spines):
# --> 916             spine.cla()
#     917
#     918         self.ignore_existing_data_limits = True
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/spines.py in cla(self)
#     168         self._position = None  # clear position
#     169         if self.axis is not None:
# --> 170             self.axis.cla()
#     171
#     172     def is_frame_like(self):
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in cla(self)
#     742         self._set_artist_props(self.label)
#     743
# --> 744         self.reset_ticks()
#     745
#     746         self.converter = None
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     756         cbook.popall(self.minorTicks)
#     757
# --> 758         self.majorTicks.extend([self._get_tick(major=True)])
#     759         self.minorTicks.extend([self._get_tick(major=False)])
#     760         self._lastNumMajorTicks = 1
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1675         else:
#    1676             tick_kw = self._minor_tick_kw
# -> 1677         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1678
#    1679     def _get_label(self):
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     401                           markersize=self._size,
#     402                           markeredgewidth=self._width, zorder=self._zorder)
# --> 403         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     404         self._set_artist_props(l)
#     405         return l
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axes/_base.py in get_xaxis_transform(self, which)
#     643         elif which == 'tick1':
#     644             # for cartesian projection, this is bottom spine
# --> 645             return self.spines['bottom'].get_spine_transform()
#     646         elif which == 'tick2':
#     647             # for cartesian projection, this is top spine
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/spines.py in get_spine_transform(self)
#     404     def get_spine_transform(self):
#     405         """get the spine transform"""
# --> 406         self._ensure_position_is_set()
#     407         what, how = self._spine_transform
#     408
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/spines.py in _ensure_position_is_set(self)
#     150             # default position
#     151             self._position = ('outward', 0.0)  # in points
# --> 152             self.set_position(self._position)
#     153
#     154     def register_axis(self, axis):
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/spines.py in set_position(self, position)
#     394
#     395         if self.axis is not None:
# --> 396             self.axis.reset_ticks()
#     397         self.stale = True
#     398
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in reset_ticks(self)
#     757
#     758         self.majorTicks.extend([self._get_tick(major=True)])
# --> 759         self.minorTicks.extend([self._get_tick(major=False)])
#     760         self._lastNumMajorTicks = 1
#     761         self._lastNumMinorTicks = 1
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    1675         else:
#    1676             tick_kw = self._minor_tick_kw
# -> 1677         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1678
#    1679     def _get_label(self):
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major)
#     148         self.apply_tickdir(tickdir)
#     149
# --> 150         self.tick1line = self._get_tick1line()
#     151         self.tick2line = self._get_tick2line()
#     152         self.gridline = self._get_gridline()
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/axis.py in _get_tick1line(self)
#     400                           linestyle='None', marker=self._tickmarkers[0],
#     401                           markersize=self._size,
# --> 402                           markeredgewidth=self._width, zorder=self._zorder)
#     403         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     404         self._set_artist_props(l)
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     351         self._color = None
#     352         self.set_color(color)
# --> 353         self._marker = MarkerStyle()
#     354         self.set_marker(marker)
#     355
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     169         # _recache() in set_marker.
#     170         self._fillstyle = fillstyle
# --> 171         self.set_marker(marker)
#     172         self.set_fillstyle(fillstyle)
#     173
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     232
#     233     def set_marker(self, marker):
# --> 234         if (iterable(marker) and len(marker) in (2, 3) and
#     235                 marker[1] in (0, 1, 2, 3)):
#     236             self._marker_function = self._set_tuple_marker
#
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/matplotlib/cbook.py in iterable(obj)
#     689     try:
#     690         iter(obj)
# --> 691     except TypeError:
#     692         return False
#     693     return True
#
# KeyboardInterrupt:

# %%
num.any(d.sort_values(by=["qO"]).index.values==d.sort_values(by=["c"],ascending=False).index.values)
# Out:
# True

# %%
k=[[k1,k2] for k1 in range(5,31) for k2 in range(5,31)]

# %%
pos=[]
for var in k:
    d=redData[num.logical_and(data.KPt==var[0],data.KO==var[1])]
    check=num.all(d.sort_values(by=["qO"]).index.values==d.sort_values(by=["c"],ascending=False).index.values)
    if check==True:
        print(var)
    pos.append(check)
# Out:
# [5, 5]
# [5, 6]
# [5, 7]
# [5, 8]
# [5, 9]
# [5, 10]
# [5, 11]
# [5, 12]
# [5, 28]
# [5, 29]
# [5, 30]
# [6, 5]
# [6, 6]
# [6, 7]
# [6, 8]
# [6, 9]
# [6, 10]
# [6, 11]
# [6, 12]
# [6, 13]
# [6, 14]
# [6, 15]
# [6, 16]
# [6, 17]
# [6, 18]
# [6, 19]
# [6, 20]
# [6, 21]
# [6, 22]
# [6, 23]
# [6, 24]
# [6, 25]
# [6, 26]
# [6, 27]
# [6, 28]
# [6, 29]
# [6, 30]
# [7, 5]
# [7, 6]
# [7, 7]
# [7, 8]
# [7, 9]
# [7, 10]
# [7, 11]
# [7, 12]
# [7, 13]
# [7, 14]
# [7, 15]
# [7, 16]
# [7, 17]
# [7, 18]
# [7, 19]
# [7, 20]
# [7, 21]
# [7, 22]
# [7, 23]
# [7, 24]
# [7, 25]
# [7, 26]
# [7, 27]
# [7, 28]
# [7, 29]
# [7, 30]
# [8, 5]
# [8, 6]
# [8, 7]
# [8, 8]
# [8, 9]
# [8, 10]
# [8, 11]
# [8, 12]
# [8, 13]
# [8, 14]
# [8, 15]
# [8, 16]
# [8, 17]
# [8, 18]
# [8, 19]
# [8, 20]
# [8, 21]
# [8, 22]
# [8, 23]
# [8, 24]
# [8, 25]
# [8, 26]
# [8, 27]
# [8, 28]
# [8, 29]
# [8, 30]
# [9, 5]
# [9, 6]
# [9, 7]
# [9, 8]
# [9, 9]
# [9, 10]
# [9, 11]
# [9, 12]
# [9, 13]
# [9, 14]
# [9, 15]
# [9, 16]
# [9, 17]
# [9, 18]
# [9, 19]
# [9, 20]
# [9, 21]
# [9, 22]
# [9, 23]
# [9, 24]
# [9, 25]
# [9, 26]
# [9, 27]
# [9, 28]
# [9, 29]
# [9, 30]
# [10, 5]
# [10, 6]
# [10, 7]
# [10, 8]
# [10, 9]
# [10, 10]
# [10, 11]
# [10, 12]
# [10, 13]
# [10, 14]
# [10, 15]
# [10, 16]
# [10, 17]
# [10, 18]
# [10, 19]
# [10, 20]
# [10, 21]
# [10, 22]
# [10, 23]
# [10, 24]
# [10, 25]
# [10, 26]
# [10, 27]
# [10, 28]
# [10, 29]
# [10, 30]
# [11, 5]
# [11, 6]
# [11, 7]
# [11, 8]
# [11, 9]
# [11, 10]
# [11, 11]
# [11, 12]
# [11, 13]
# [11, 14]
# [11, 15]
# [11, 16]
# [11, 17]
# [11, 18]
# [11, 19]
# [11, 20]
# [11, 21]
# [11, 22]
# [11, 23]
# [11, 24]
# [11, 25]
# [11, 26]
# [11, 27]
# [11, 28]
# [11, 29]
# [11, 30]
# [12, 5]
# [12, 6]
# [12, 7]
# [12, 8]
# [12, 9]
# [12, 10]
# [12, 11]
# [12, 12]
# [12, 13]
# [12, 14]
# [12, 15]
# [12, 16]
# [12, 17]
# [12, 18]
# [12, 19]
# [12, 20]
# [12, 21]
# [12, 22]
# [12, 23]
# [12, 24]
# [12, 25]
# [12, 26]
# [12, 27]
# [12, 28]
# [12, 29]
# [12, 30]
# [13, 5]
# [13, 6]
# [13, 7]
# [13, 8]
# [13, 9]
# [13, 10]
# [13, 11]
# [13, 12]
# [13, 13]
# [13, 14]
# [13, 15]
# [13, 16]
# [13, 17]
# [13, 18]
# [13, 19]
# [13, 20]
# [13, 21]
# [13, 22]
# [13, 23]
# [13, 24]
# [13, 25]
# [13, 26]
# [13, 27]
# [13, 28]
# [13, 29]
# [13, 30]
# [14, 5]
# [14, 6]
# [14, 7]
# [14, 8]
# [14, 9]
# [14, 10]
# [14, 11]
# [14, 12]
# [14, 13]
# [14, 14]
# [14, 15]
# [14, 16]
# [14, 17]
# [14, 18]
# [14, 19]
# [14, 20]
# [14, 21]
# [14, 22]
# [14, 23]
# [14, 24]
# [14, 25]
# [14, 26]
# [14, 27]
# [14, 28]
# [14, 29]
# [14, 30]
# [15, 5]
# [15, 6]
# [15, 7]
# [15, 8]
# [15, 9]
# [15, 10]
# [15, 11]
# [15, 12]
# [15, 13]
# [15, 14]
# [15, 15]
# [15, 16]
# [15, 17]
# [15, 18]
# [15, 19]
# [15, 20]
# [15, 21]
# [15, 22]
# [15, 23]
# [15, 24]
# [15, 25]
# [15, 26]
# [15, 27]
# [15, 28]
# [15, 29]
# [15, 30]
# [16, 5]
# [16, 6]
# [16, 7]
# [16, 8]
# [16, 9]
# [16, 10]
# [16, 11]
# [16, 12]
# [16, 13]
# [16, 14]
# [16, 15]
# [16, 16]
# [16, 17]
# [16, 18]
# [16, 19]
# [16, 20]
# [16, 21]
# [16, 22]
# [16, 23]
# [16, 24]
# [16, 25]
# [16, 26]
# [16, 27]
# [16, 28]
# [16, 29]
# [16, 30]
# [17, 5]
# [17, 6]
# [17, 7]
# [17, 8]
# [17, 9]
# [17, 10]
# [17, 11]
# [17, 12]
# [17, 13]
# [17, 14]
# [17, 15]
# [17, 16]
# [17, 17]
# [17, 18]
# [17, 19]
# [17, 20]
# [17, 21]
# [17, 22]
# [17, 23]
# [17, 24]
# [17, 25]
# [17, 26]
# [17, 27]
# [17, 28]
# [17, 29]
# [17, 30]
# [18, 5]
# [18, 6]
# [18, 7]
# [18, 8]
# [18, 9]
# [18, 10]
# [18, 11]
# [18, 12]
# [18, 13]
# [18, 14]
# [18, 15]
# [18, 16]
# [18, 17]
# [18, 18]
# [18, 19]
# [18, 20]
# [18, 21]
# [18, 22]
# [18, 23]
# [18, 24]
# [18, 25]
# [18, 26]
# [18, 27]
# [18, 28]
# [18, 29]
# [18, 30]
# [19, 5]
# [19, 6]
# [19, 7]
# [19, 8]
# [19, 9]
# [19, 10]
# [19, 11]
# [19, 12]
# [19, 13]
# [19, 14]
# [19, 15]
# [19, 16]
# [19, 17]
# [19, 18]
# [19, 19]
# [19, 20]
# [19, 21]
# [19, 22]
# [19, 23]
# [19, 24]
# [19, 25]
# [19, 26]
# [19, 27]
# [19, 28]
# [19, 29]
# [19, 30]
# [20, 5]
# [20, 6]
# [20, 7]
# [20, 8]
# [20, 9]
# [20, 10]
# [20, 11]
# [20, 12]
# [20, 13]
# [20, 14]
# [20, 15]
# [20, 16]
# [20, 17]
# [20, 18]
# [20, 19]
# [20, 20]
# [20, 21]
# [20, 22]
# [20, 23]
# [20, 24]
# [20, 25]
# [20, 26]
# [20, 27]
# [20, 28]
# [20, 29]
# [20, 30]
# [21, 5]
# [21, 6]
# [21, 7]
# [21, 8]
# [21, 9]
# [21, 10]
# [21, 11]
# [21, 12]
# [21, 13]
# [21, 14]
# [21, 15]
# [21, 16]
# [21, 17]
# [21, 18]
# [21, 19]
# [21, 20]
# [21, 21]
# [21, 22]
# [21, 23]
# [21, 24]
# [21, 25]
# [21, 26]
# [21, 27]
# [21, 28]
# [21, 29]
# [21, 30]
# [22, 5]
# [22, 6]
# [22, 7]
# [22, 8]
# [22, 9]
# [22, 10]
# [22, 11]
# [22, 12]
# [22, 13]
# [22, 14]
# [22, 15]
# [22, 16]
# [22, 17]
# [22, 18]
# [22, 19]
# [22, 20]
# [22, 21]
# [22, 22]
# [22, 23]
# [22, 24]
# [22, 25]
# [22, 26]
# [22, 27]
# [22, 28]
# [22, 29]
# [22, 30]
# [23, 5]
# [23, 6]
# [23, 7]
# [23, 8]
# [23, 9]
# [23, 10]
# [23, 11]
# [23, 12]
# [23, 13]
# [23, 14]
# [23, 15]
# [23, 16]
# [23, 17]
# [23, 18]
# [23, 19]
# [23, 20]
# [23, 21]
# [23, 22]
# [23, 23]
# [23, 24]
# [23, 25]
# [23, 26]
# [23, 27]
# [23, 28]
# [23, 29]
# [23, 30]
# [24, 5]
# [24, 6]
# [24, 7]
# [24, 8]
# [24, 9]
# [24, 10]
# [24, 11]
# [24, 12]
# [24, 13]
# [24, 14]
# [24, 15]
# [24, 16]
# [24, 17]
# [24, 18]
# [24, 19]
# [24, 20]
# [24, 21]
# [24, 22]
# [24, 23]
# [24, 24]
# [24, 25]
# [24, 26]
# [24, 27]
# [24, 28]
# [24, 29]
# [24, 30]
# [25, 5]
# [25, 6]
# [25, 7]
# [25, 8]
# [25, 9]
# [25, 10]
# [25, 11]
# [25, 12]
# [25, 13]
# [25, 14]
# [25, 15]
# [25, 16]
# [25, 17]
# [25, 18]
# [25, 19]
# [25, 20]
# [25, 21]
# [25, 22]
# [25, 23]
# [25, 24]
# [25, 25]
# [25, 26]
# [25, 27]
# [25, 28]
# [25, 29]
# [25, 30]
# [26, 5]
# [26, 6]
# [26, 7]
# [26, 8]
# [26, 9]
# [26, 10]
# [26, 11]
# [26, 12]
# [26, 13]
# [26, 14]
# [26, 15]
# [26, 16]
# [26, 17]
# [26, 18]
# [26, 19]
# [26, 20]
# [26, 21]
# [26, 22]
# [26, 23]
# [26, 24]
# [26, 25]
# [26, 26]
# [26, 27]
# [26, 28]
# [26, 29]
# [26, 30]
# [27, 5]
# [27, 6]
# [27, 7]
# [27, 8]
# [27, 9]
# [27, 10]
# [27, 11]
# [27, 12]
# [27, 13]
# [27, 14]
# [27, 15]
# [27, 16]
# [27, 17]
# [27, 18]
# [27, 19]
# [27, 20]
# [27, 21]
# [27, 22]
# [27, 23]
# [27, 24]
# [27, 25]
# [27, 26]
# [27, 27]
# [27, 28]
# [27, 29]
# [27, 30]
# [28, 5]
# [28, 6]
# [28, 7]
# [28, 8]
# [28, 9]
# [28, 10]
# [28, 11]
# [28, 12]
# [28, 13]
# [28, 14]
# [28, 15]
# [28, 16]
# [28, 17]
# [28, 18]
# [28, 19]
# [28, 20]
# [28, 21]
# [28, 22]
# [28, 23]
# [28, 24]
# [28, 25]
# [28, 26]
# [28, 27]
# [28, 28]
# [28, 29]
# [28, 30]
# [29, 5]
# [29, 6]
# [29, 7]
# [29, 8]
# [29, 9]
# [29, 10]
# [29, 11]
# [29, 12]
# [29, 13]
# [29, 14]
# [29, 15]
# [29, 16]
# [29, 17]
# [29, 18]
# [29, 19]
# [29, 20]
# [29, 21]
# [29, 22]
# [29, 23]
# [29, 24]
# [29, 25]
# [29, 26]
# [29, 27]
# [29, 28]
# [29, 29]
# [29, 30]
# [30, 5]
# [30, 6]
# [30, 7]
# [30, 8]
# [30, 9]
# [30, 10]
# [30, 11]
# [30, 12]
# [30, 13]
# [30, 14]
# [30, 15]
# [30, 16]
# [30, 17]
# [30, 18]
# [30, 19]
# [30, 20]
# [30, 21]
# [30, 22]
# [30, 23]
# [30, 24]
# [30, 25]
# [30, 26]
# [30, 27]
# [30, 28]
# [30, 29]
# [30, 30]

# %%
pos=[]
for var in range(5,31):
    d=redData[num.logical_and(data.KPt==17,data.KO==var)]
    check=num.all(d.sort_values(by=["qO"]).index.values==d.sort_values(by=["c"],ascending=False).index.values)
    if check==True:
        print(var)
    pos.append(check)
# Out:
# 5
# 6
# 7
# 8
# 9
# 10
# 11
# 12
# 13
# /home/hbhattar/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   app.launch_new_instance()

# %%
val=[]
for var in range(5,100):
    mat=num.array([[14+2,0.15,0],[0.15,var+5,0.15],[0,0.15,57.544+8]])
    eig=num.sort(num.linalg.eigvals(mat))
    val.append(eig)

# %%
lab.plot(num.matrix(val)[:,0])
