# %%
import numpy as num
import matplotlib.pyplot as plt

# Determine the index of the atoms having same z-value 
#list the index of atoms in same plane
Ofile="Pt100GroundedImageOneNew.xyz"
fileOmd=open(Ofile)
linesOmd=fileOmd.readlines()

posz=[]
for line in linesOmd:
    linesSplit=str.split(line)
    length=len(linesSplit)
    
    if(linesSplit[0]!="Na+"):
        posz.append(float(linesSplit[3]))
    
    else:
        break;
       
        


lengthPosz=len(posz)
sortPos=num.argsort(posz) # sorts the list with arguments as output i.e position as output



arrSortPos=num.array(sortPos)

# Make the different plane using the index of the atoms
indexPoszSort=[]
indexPoszSort.append(0)
init=posz[sortPos[0]]
for i in range(0,lengthPosz):
    if(posz[sortPos[i]]!=init):
        indexPoszSort.append(i)
    init=posz[sortPos[i]]


# X Y and C arrays for different atoms.

filexyz=open(Ofile)
linesXYZ=filexyz.readlines()
atomNumber=lengthPosz;
layerCrystal=len(indexPoszSort)+1
numFrames=100
x=num.zeros((numFrames+1,atomNumber))
y=num.zeros((numFrames+1,atomNumber))
c=num.zeros((numFrames+1,atomNumber))

count=0
index=0

for line in linesXYZ:
    lineApp=str.split(line);
    
    if(lineApp[0]=="Na+"):
        count=count+1
        index=0
        continue
    else:
        x[count][index]=float(lineApp[1])
        y[count][index]=float(lineApp[2])
        c[count][index]=float(lineApp[4])
        index=index+1
        
        
indexPoszSort.append(atomNumber)

#scatter plot of top layer
frame=5
Layer=layerCrystal-1
print indexPoszSort
for frameNo in range(frame+1):
    fig=plt.figure()
    for zLayer in range(1,Layer+1):
        layer=range(indexPoszSort[zLayer-1],indexPoszSort[zLayer])
        position=arrSortPos[layer]
        charge=c[frameNo,position]
        xx= x[frameNo,position]
        yy= y[frameNo,position]
        scaled_c = (charge - charge.min()) / charge.ptp()
        colors = plt.cm.coolwarm(scaled_c)
        sign=[];
        for var in charge:
            if (var<0):
                sign.append("blue");
            elif(var>0):
                sign.append("red");
            else:
                sign.append("black")
        ax1 = fig.add_subplot(1,1,zLayer)
        cmax=c.max()
        cmin=c.min()
        plt.scatter(xx, yy, c=charge, s=50, cmap='jet',edgecolor=sign,linewidth=1,vmin=-0.01303879,vmax=-0.00906235)
        if (zLayer==1):
            plt. colorbar()
        plt.grid()
        
    fileName=str(frameNo)+".jpeg"
    plt.title(str(frameNo))
    plt.savefig(fileName)
# Out:
# [0, 98]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-cf5e0327ba6a> in <module>()
#      94         cmax=c.max()
#      95         cmin=c.min()
# ---> 96         cp = plt.contour(xx, yy, c)
#      97         plt.clabel(cp, inline=True,
#      98           fontsize=10)
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in contour(*args, **kwargs)
#    2764         ax.hold(hold)
#    2765     try:
# -> 2766         ret = ax.contour(*args, **kwargs)
#    2767     finally:
#    2768         ax.hold(washold)
#
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1812                     warnings.warn(msg % (label_namer, func.__name__),
#    1813                                   RuntimeWarning, stacklevel=2)
# -> 1814             return func(ax, *args, **kwargs)
#    1815         pre_doc = inner.__doc__
#    1816         if pre_doc is None:
#
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in contour(self, *args, **kwargs)
#    5642             self.cla()
#    5643         kwargs['filled'] = False
# -> 5644         return mcontour.QuadContourSet(self, *args, **kwargs)
#    5645     contour.__doc__ = mcontour.QuadContourSet.contour_doc
#    5646
#
# /usr/lib/python2.7/dist-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#    1422         are described in QuadContourSet.contour_doc.
#    1423         """
# -> 1424         ContourSet.__init__(self, ax, *args, **kwargs)
#    1425
#    1426     def _process_args(self, *args, **kwargs):
#
# /usr/lib/python2.7/dist-packages/matplotlib/contour.pyc in __init__(self, ax, *args, **kwargs)
#     861         self._transform = kwargs.get('transform', None)
#     862
# --> 863         self._process_args(*args, **kwargs)
#     864         self._process_levels()
#     865
#
# /usr/lib/python2.7/dist-packages/matplotlib/contour.pyc in _process_args(self, *args, **kwargs)
#    1443                 self._corner_mask = mpl.rcParams['contour.corner_mask']
#    1444
# -> 1445             x, y, z = self._contour_args(args, kwargs)
#    1446
#    1447             _mask = ma.getmask(z)
#
# /usr/lib/python2.7/dist-packages/matplotlib/contour.pyc in _contour_args(self, args, kwargs)
#    1526             args = args[1:]
#    1527         elif Nargs <= 4:
# -> 1528             x, y, z = self._check_xyz(args[:3], kwargs)
#    1529             args = args[3:]
#    1530         else:
#
# /usr/lib/python2.7/dist-packages/matplotlib/contour.pyc in _check_xyz(self, args, kwargs)
#    1576
#    1577             if ny != Ny:
# -> 1578                 raise TypeError("Length of y must be number of rows in z.")
#    1579
#    1580             x, y = np.meshgrid(x, y)
#
# TypeError: Length of y must be number of rows in z.
