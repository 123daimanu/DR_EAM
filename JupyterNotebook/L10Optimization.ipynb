# %%
from matplotlib import pyplot as plt
from matplotlib import rcParams
import numpy as num
import pandas as pan
import pylab as lab
# %matplotlib inline

# %%
params = {
    'font.family':'serif',
   'axes.labelsize': 12,
   'font.size': 12,
   'legend.fontsize': 12,
   'xtick.labelsize': 12,
   'ytick.labelsize': 12,
   'text.usetex': False,
   'figure.figsize': [6, 6]
   }
rcParams.update(params)

# %%
data1=num.loadtxt("../L10/AlMg.Zhoulandscape")
data1
# Out:
# array([[  4.150471,   4.099286, -58.338372],
#        [  4.150471,   4.113571, -58.498437],
#        [  4.150471,   4.127857, -58.645613],
#        ...,
#        [  4.4219  ,   4.342143, -59.14107 ],
#        [  4.4219  ,   4.356429, -59.059113],
#        [  4.4219  ,   4.370714, -58.970475]])

# %%
data1=data1[data1[:,2]<0]
data1
# Out:
# array([[  4.150471,   4.099286, -58.338372],
#        [  4.150471,   4.113571, -58.498437],
#        [  4.150471,   4.127857, -58.645613],
#        ...,
#        [  4.4219  ,   4.342143, -59.14107 ],
#        [  4.4219  ,   4.356429, -59.059113],
#        [  4.4219  ,   4.370714, -58.970475]])

# %%
#data1=num.loadtxt("../L10/PtFeL10/PtFeCoarseRc8MinCG.landscape")
plt.scatter(data1[:,0],data1[:,1],c=data1[:,2],cmap="jet",s=500)
plt.xlabel("c")
plt.ylabel("a")
plt.colorbar()
lab.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

#data1=num.loadtxt("../L10/PtFeL10/PtFeCoarseRc8MinCG.landscape")

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x =data1[:,0]
y =data1[:,1]
z =-data1[:,2]


ax.scatter(x, y, z, c=z, marker='o',cmap="Reds")

ax.set_xlabel('X Label')
ax.set_ylabel('Y Label')
ax.set_zlabel('Z Label')
#ax.view_init(50, 120)
plt.show()

# %%
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np
#data1=num.loadtxt("../L10/PtFeL10/PtFeCoarseRc8MinCG.landscape")
x = data1[:,0]
y= data1[:,1]
z=data1[:,2]
trace1 = go.Scatter3d(
    x=x,
    y=y,
    z=-z,
    mode='markers',
    marker=dict(
        size=5,
        color=z,                # set color to an array/list of desired values
        colorscale='Jet',   # choose a colorscale
        opacity=5
    )
)

data = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-scatter-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~nanukanchisanu/30.embed" height="525px" width="100%"></iframe>

# %%
lab.plot(num.multiply(num.multiply(data1[:,0],data1[:,1]),data1[:,1]),data1[:,2],'o')
num.multiply(num.multiply(data1[:,0],data1[:,1]),data1[:,1])
# Out:
# array([ 78.61329219,  79.16421595,  79.7171022 ,  80.27191242,
#         80.82864662,  81.38726562,  81.94784765,  82.51035364,
#         83.07474404,  83.64109786,  84.20937566,  84.77957744,
#         85.35166307,  85.92571267,  86.50168624,  87.07954327,
#         87.65936467,  88.24111004,  88.82477939,  89.41033166,
#         78.85155588,  79.4041494 ,  79.95871135,  80.51520311,
#         81.07362468,  81.63393676,  82.19621781,  82.76042867,
#         83.32652965,  83.89459999,  84.46460014,  85.0365301 ,
#         85.61034964,  86.18613908,  86.76385833,  87.34346675,
#         87.92504549,  88.50855403,  89.09399239,  89.68131937,
#         79.08981957,  79.64408285,  80.20032051,  80.7584938 ,
#         81.31860274,  81.8806079 ,  82.44458798,  83.01050371,
#         83.57831525,  84.14810212,  84.71982462,  85.29348277,
#         85.8690362 ,  86.44656549,  87.02603042,  87.60739023,
#         88.19072631,  88.77599802,  89.36320538,  89.95230707,
# ...

# %%
d=num.argsort(data1[:,2])
plt.plot(data1[d,2])
plt.ylim([-130000,-132000])
# Out:
# (-130000, -132000)

# %%
data1[d][0]
# Out:
# array([   3.76   ,    3.68   , -124.22422])

# %%
file=open("/home/hbhattar/afs/Hemanta/metals/L10/minStrucutreCoarse.info",'w')
file.write("#name\tc\ta\tenergy\n")

names=["AgTi","AlMg","AlTi","AuCu","NiFe","NiMg","PdFe","PdTi","PtCo","PtFe","PtNi","ZrMg"]
#names=["PtFe"]
for name in names:
    try:
        data1=num.loadtxt("../L10/%s.landscape"%(name))
        d=num.argsort(data1[:,2])
        plt.plot(data1[d,2],'o')
        plt.show()
        optStrucutre=data1[d][0]
        
        file.write("%s\t%f\t%f\t%f\n"%(name,optStrucutre[0],optStrucutre[1],optStrucutre[2]))
        fig = plt.figure()
    
        ax = fig.add_subplot(111, projection='3d')

        x =data1[:,0]
        y =data1[:,1]
        z =data1[:,2]


        ax.scatter(x, y, z, c=z, marker='o',cmap="Reds")

        ax.set_xlabel('X Label')
        ax.set_ylabel('Y Label')
        ax.set_zlabel('Z Label')
        #ax.view_init(50, 120)
        plt.show()
        print(name,optStrucutre*7)
        print("++++++++++++++++++++++++++++++")
        
    except:
        print("%s not found"%(name))
        print("++++++++++++++++++++++++++++++")
    
file.close()
# Out:
# AgTi [  29.830003   28.660597 -638.047396]
# ++++++++++++++++++++++++++++++
# AlMg [  30.948799   29.403199 -419.227004]
# ++++++++++++++++++++++++++++++
# AlTi [  29.913702   28.725697 -692.521123]
# ++++++++++++++++++++++++++++++
# AuCu [  23.673202   28.826798 -655.714388]
# ++++++++++++++++++++++++++++++
# NiFe [  24.7359     24.624502 -728.884947]
# ++++++++++++++++++++++++++++++
# NiMg [  28.642201   28.192997 -404.995626]
# ++++++++++++++++++++++++++++++
# PdFe [  24.787798   26.750003 -689.793468]
# ++++++++++++++++++++++++++++++
# PdTi [  27.849899   28.670299 -752.059441]
# ++++++++++++++++++++++++++++++
# PtCo [  24.381602   27.050303 -891.343264]
# ++++++++++++++++++++++++++++++
# PtFe [  24.4986     26.3921   -914.342499]
# ++++++++++++++++++++++++++++++
# PtNi [  24.165302   26.992098 -897.886171]
# ++++++++++++++++++++++++++++++
# ZrMg [  33.994898   29.587201 -650.622553]
# ++++++++++++++++++++++++++++++

# %%
print?
