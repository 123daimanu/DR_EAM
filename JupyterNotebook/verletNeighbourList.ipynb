# %%
import numpy as num

# %%
atomPos=num.random.random(10)
atomPos
# Out:
# array([ 0.71497861,  0.57913829,  0.28768648,  0.21948453,  0.85167861,
#         0.13872583,  0.98418003,  0.3368517 ,  0.84917111,  0.67490672])

# %%
rCut=0.2
d=0.01
rVerlet=d+rCut

# %%
listEntry=num.zeros(len(atomPos))
listPos=[]
count=-1
for pos1 in range(len(atomPos)-1):
    print("for %d "%(pos1))
    for pos2 in range(pos1+1,len(atomPos)):
        if(abs(atomPos[pos1]-atomPos[pos2]))<rVerlet:
            print(abs(atomPos[pos1]-atomPos[pos2]))
            count=count+1
            
            listEntry[pos1]=count
            listPos.append(pos2)
listEntry,listPos
# Out:
# for 0
# 0.135840313976
# 0.136700000507
# 0.134192502851
# 0.0400718849917
# for 1
# 0.0957684289841
# for 2
# 0.0682019569944
# 0.148960651318
# 0.0491652163102
# for 3
# 0.0807586943235
# 0.117367173305
# for 4
# 0.132501421509
# 0.00250749765571
# 0.176771885498
# for 5
# 0.198125867628
# for 6
# 0.135008919165
# for 7
# for 8
# 0.174264387843
# (array([  3.,   4.,   7.,   9.,  12.,  13.,  14.,   0.,  15.,   0.]),
#  [1, 4, 8, 9, 9, 3, 5, 7, 5, 7, 6, 8, 9, 7, 8, 9])

# %%
from numpy import array
out=[[10, 0, array([  5.95126189e-11,  -2.59770796e-05])],
 [10, 0.0001, array([  5.68913393e-09,  -2.54743748e-05])],
 [10, 0.001, array([  6.04131111e-08,  -2.05137753e-05])],
 [10, 0.01, array([  6.06707175e-07,   2.87621515e-05])],
 [10, 0.1, array([  6.07373565e-06,   5.22151748e-04])],
 [10, 0.15, array([  9.11025450e-06,   7.96056780e-04])],
 [10, 0.2, array([  1.21479072e-05,   1.07001522e-03])],
 [10, 0.25, array([  1.51862988e-05,   1.34399492e-03])],
 [10, 0.3, array([  1.82251427e-05,   1.61795064e-03])],
 [10, 0.35, array([  2.12643865e-05,   1.89186260e-03])],
 [10, 0.4, array([  2.43051485e-05,   2.16590883e-03])],
 [10, 0.45, array([  2.73466047e-05,   2.43990522e-03])],
 [10, 0.5, array([  3.03898933e-05,   2.71405109e-03])],
 [10, 0.55, array([  3.34338995e-05,   2.98817411e-03])],
 [10, 0.6, array([  3.64795627e-05,   3.26240052e-03])],
 [10, 0.65, array([  3.95272750e-05,   3.53676849e-03])],
 [12, 0, array([  4.61966479e-11,  -2.47390316e-05])],
 [12, 0.0001, array([  5.85376624e-09,  -2.42158992e-05])],
 [12, 0.001, array([  5.95332605e-08,  -1.93798713e-05])],
 [12, 0.01, array([  5.95360927e-07,   2.89771804e-05])],
 [12, 0.1, array([  5.89853262e-06,   5.07562026e-04])],
 [12, 0.15, array([  8.84867455e-06,   7.73685436e-04])],
 [12, 0.2, array([  1.17992904e-05,   1.03979801e-03])],
 [12, 0.25, array([  1.47502946e-05,   1.30593079e-03])],
 [12, 0.3, array([  1.77025957e-05,   1.57208606e-03])],
 [12, 0.35, array([  2.06558406e-05,   1.83830508e-03])],
 [12, 0.4, array([  2.36103561e-05,   2.10456344e-03])],
 [12, 0.45, array([  2.65666505e-05,   2.37095649e-03])],
 [12, 0.5, array([  2.95248820e-05,   2.63746083e-03])],
 [12, 0.55, array([  3.24851224e-05,   2.90408918e-03])],
 [12, 0.6, array([  3.54472475e-05,   3.17084417e-03])],
 [12, 0.65, array([  3.84111444e-05,   3.43769522e-03])],
 [14, 0, array([  2.72652506e-11,  -2.36195074e-05])],
 [14, 0.0001, array([  5.68781255e-09,  -2.31107391e-05])],
 [14, 0.001, array([  5.68699188e-08,  -1.84935861e-05])],
 [14, 0.01, array([  5.67613161e-07,   2.76018907e-05])],
 [14, 0.1, array([  5.68192677e-06,   4.89163709e-04])],
 [14, 0.15, array([  8.52348494e-06,   7.45507214e-04])],
 [14, 0.2, array([  1.13647813e-05,   1.00176916e-03])],
 [14, 0.25, array([  1.42073836e-05,   1.25809505e-03])],
 [14, 0.3, array([  1.70495929e-05,   1.51435014e-03])],
 [14, 0.35, array([  1.98927758e-05,   1.77063877e-03])],
 [14, 0.4, array([  2.27373062e-05,   2.02701671e-03])],
 [14, 0.45, array([  2.55819200e-05,   2.28335493e-03])],
 [14, 0.5, array([  2.84275603e-05,   2.53971787e-03])],
 [14, 0.55, array([  3.12743948e-05,   2.79613242e-03])],
 [14, 0.6, array([  3.41232068e-05,   3.05271268e-03])],
 [14, 0.65, array([  3.69726703e-05,   3.30928737e-03])],
 [16, 0, array([  3.03701149e-10,  -2.26308224e-05])],
 [16, 0.0001, array([  5.76193027e-09,  -2.21320466e-05])],
 [16, 0.001, array([  5.62126375e-08,  -1.75913485e-05])],
 [16, 0.01, array([  5.59801881e-07,   2.78520958e-05])],
 [16, 0.1, array([  5.54359280e-06,   4.77673439e-04])],
 [16, 0.15, array([  8.31539578e-06,   7.27737352e-04])],
 [16, 0.2, array([  1.10887317e-05,   9.77889087e-04])],
 [16, 0.25, array([  1.38615380e-05,   1.22794256e-03])],
 [16, 0.3, array([  1.66360421e-05,   1.47810473e-03])],
 [16, 0.35, array([  1.94108809e-05,   1.72825808e-03])],
 [16, 0.4, array([  2.21872762e-05,   1.97852840e-03])],
 [16, 0.45, array([  2.49647609e-05,   2.22883144e-03])],
 [16, 0.5, array([  2.77440885e-05,   2.47926727e-03])],
 [16, 0.55, array([  3.05250154e-05,   2.72978727e-03])],
 [16, 0.6, array([  3.33077445e-05,   2.98044770e-03])],
 [16, 0.65, array([  3.60924866e-05,   3.23122651e-03])],
 [18, 0, array([  2.38624580e-10,  -2.16494382e-05])],
 [18, 0.0001, array([  5.21535609e-09,  -2.11905042e-05])],
 [18, 0.001, array([  5.32946483e-08,  -1.68504706e-05])],
 [18, 0.01, array([  5.33370126e-07,   2.65182154e-05])],
 [18, 0.1, array([  5.33300146e-06,   4.59603557e-04])],
 [18, 0.15, array([  7.99963480e-06,   7.00172316e-04])],
 [18, 0.2, array([  1.06666224e-05,   9.40728985e-04])],
 [18, 0.25, array([  1.33345167e-05,   1.18132090e-03])],
 [18, 0.3, array([  1.60024755e-05,   1.42189847e-03])],
 [18, 0.35, array([  1.86710658e-05,   1.66246311e-03])],
 [18, 0.4, array([  2.13405572e-05,   1.90308796e-03])],
 [18, 0.45, array([  2.40105541e-05,   2.14371480e-03])],
 [18, 0.5, array([  2.66817063e-05,   2.38440996e-03])],
 [18, 0.55, array([  2.93534617e-05,   2.62511508e-03])],
 [18, 0.6, array([  3.20267222e-05,   2.86590437e-03])],
 [18, 0.65, array([  3.47014384e-05,   3.10679987e-03])],
 [20, 0, array([ -2.70482372e-11,  -2.09313374e-05])],
 [20, 0.0001, array([  5.25452854e-09,  -2.04574418e-05])],
 [20, 0.001, array([  5.28972351e-08,  -1.61540224e-05])],
 [20, 0.01, array([  5.23404804e-07,   2.64183832e-05])],
 [20, 0.1, array([  5.23429685e-06,   4.51504973e-04])],
 [20, 0.15, array([  7.85188169e-06,   6.87658880e-04])],
 [20, 0.2, array([  1.04700075e-05,   9.23819683e-04])],
 [20, 0.25, array([  1.30886956e-05,   1.15999037e-03])],
 [20, 0.3, array([  1.57078868e-05,   1.39618133e-03])],
 [20, 0.35, array([  1.83276068e-05,   1.63237738e-03])],
 [20, 0.4, array([  2.09487030e-05,   1.86865916e-03])],
 [20, 0.45, array([  2.35706978e-05,   2.10498572e-03])],
 [20, 0.5, array([  2.61940473e-05,   2.34140367e-03])],
 [20, 0.55, array([  2.88189436e-05,   2.57791548e-03])],
 [20, 0.6, array([  3.14451574e-05,   2.81452139e-03])],
 [20, 0.65, array([  3.40729554e-05,   3.05122386e-03])],
 [22, 0, array([  1.17208273e-10,  -2.00632684e-05])],
 [22, 0.0001, array([  5.12588366e-09,  -1.96087749e-05])],
 [22, 0.001, array([  4.99431434e-08,  -1.55654392e-05])],
 [22, 0.01, array([  5.02261909e-07,   2.53137962e-05])],
 [22, 0.1, array([  5.02482832e-06,   4.33407092e-04])],
 [22, 0.15, array([  7.53731781e-06,   6.60070544e-04])],
 [22, 0.2, array([  1.00503942e-05,   8.86765321e-04])],
 [22, 0.25, array([  1.25633722e-05,   1.11339867e-03])],
 [22, 0.3, array([  1.50776964e-05,   1.34013561e-03])],
 [22, 0.35, array([  1.75919119e-05,   1.56681766e-03])],
 [22, 0.4, array([  2.01072493e-05,   1.79355757e-03])],
 [22, 0.45, array([  2.26235197e-05,   2.02036963e-03])],
 [22, 0.5, array([  2.51402188e-05,   2.24716925e-03])],
 [22, 0.55, array([  2.76582021e-05,   2.47404943e-03])],
 [22, 0.6, array([  3.01772779e-05,   2.70099597e-03])],
 [22, 0.65, array([  3.26977084e-05,   2.92801277e-03])],
 [24, 0, array([  1.29017313e-11,  -1.94288307e-05])],
 [24, 0.0001, array([  4.81010447e-09,  -1.90091328e-05])],
 [24, 0.001, array([  5.01650519e-08,  -1.49093322e-05])],
 [24, 0.01, array([  4.95781854e-07,   2.54112875e-05])],
 [24, 0.1, array([  4.95770704e-06,   4.28038854e-04])],
 [24, 0.15, array([  7.43657333e-06,   6.51671824e-04])],
 [24, 0.2, array([  9.91589210e-06,   8.75331105e-04])],
 [24, 0.25, array([  1.23955754e-05,   1.09898471e-03])],
 [24, 0.3, array([  1.48759826e-05,   1.32268197e-03])],
 [24, 0.35, array([  1.73566237e-05,   1.54634814e-03])],
 [24, 0.4, array([  1.98380854e-05,   1.77007101e-03])],
 [24, 0.45, array([  2.23206244e-05,   1.99386925e-03])],
 [24, 0.5, array([  2.48040063e-05,   2.21768600e-03])],
 [24, 0.55, array([  2.72880882e-05,   2.44154982e-03])],
 [24, 0.6, array([  2.97733113e-05,   2.66548856e-03])],
 [24, 0.65, array([  3.22601268e-05,   2.88952276e-03])],
 [26, 0, array([  2.84573229e-11,  -1.86511138e-05])],
 [26, 0.0001, array([  4.68560044e-09,  -1.82253306e-05])],
 [26, 0.001, array([  4.74633343e-08,  -1.43716160e-05])],
 [26, 0.01, array([  4.75400414e-07,   2.42537348e-05])],
 [26, 0.1, array([  4.75588056e-06,   4.10510161e-04])],
 [26, 0.15, array([  7.13358401e-06,   6.25015884e-04])],
 [26, 0.2, array([  9.51230217e-06,   8.39589848e-04])],
 [26, 0.25, array([  1.18911007e-05,   1.05414450e-03])],
 [26, 0.3, array([  1.42703341e-05,   1.26870802e-03])],
 [26, 0.35, array([  1.66504390e-05,   1.48330843e-03])],
 [26, 0.4, array([  1.90316457e-05,   1.69799262e-03])],
 [26, 0.45, array([  2.14134939e-05,   1.91269633e-03])],
 [26, 0.5, array([  2.37962284e-05,   2.12744786e-03])],
 [26, 0.55, array([  2.61803219e-05,   2.34229195e-03])],
 [26, 0.6, array([  2.85654290e-05,   2.55719649e-03])],
 [26, 0.65, array([  3.09520363e-05,   2.77220866e-03])],
 [28, 0, array([  2.51326398e-10,  -1.80485830e-05])],
 [28, 0.0001, array([  4.60380020e-09,  -1.76559955e-05])],
 [28, 0.001, array([  4.70554245e-08,  -1.38305691e-05])],
 [28, 0.01, array([  4.69513151e-07,   2.43012496e-05])],
 [28, 0.1, array([  4.69404581e-06,   4.05507958e-04])],
 [28, 0.15, array([  7.04130819e-06,   6.17282522e-04])],
 [28, 0.2, array([  9.38883972e-06,   8.29067065e-04])],
 [28, 0.25, array([  1.17365058e-05,   1.04081383e-03])],
 [28, 0.3, array([  1.40844865e-05,   1.25257152e-03])],
 [28, 0.35, array([  1.64327294e-05,   1.46432353e-03])],
 [28, 0.4, array([  1.87816750e-05,   1.67611186e-03])],
 [28, 0.45, array([  2.11311712e-05,   1.88792695e-03])],
 [28, 0.5, array([  2.34809925e-05,   2.09974701e-03])],
 [28, 0.55, array([  2.58318262e-05,   2.31161192e-03])],
 [28, 0.6, array([  2.81829619e-05,   2.52347605e-03])],
 [28, 0.65, array([  3.05348046e-05,   2.73539814e-03])]]

# %%
# Out:
# [10, 0.001, array([  6.04131111e-08,  -2.05137753e-05])]

# %%
listPos[25]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-80-39478818a7c8> in <module>()
# ----> 1 listPos[25]
#
# IndexError: list index out of range
